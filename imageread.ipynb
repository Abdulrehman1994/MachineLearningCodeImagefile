# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load single image
# Python program to read 
# image using matplotlib 

# importing matplotlib modules 
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 

# Read Images 
img = mpimg.imread('/content/drive/My Drive/images/Faisal-Mosque-from-Damn-e-koh.jpg') 

# Output Images 
plt.imshow(img)

# %%
import cv2 
import os 
import glob 
#img_dir = "/content/drive/My Drive/cities" # Enter Directory of all images  
#data_path = os.path.join(img_dir,'*g') 
#files = glob.glob(data_path) 
#data = [] 
#for f1 in files: 
#   img = cv2.imread(f1) 
#   data.append(img) 
def load_images_from_folder(folder):
  images=[]
  for filename in os.listdir(img_dir):
    img=cv2.imread(os.path.join(folder,filename))
    if img is not None:
      images.append(img)
  return images
img_dir="/content/drive/My Drive/cities"
image=load_images_from_folder(img_dir)
load_images_from_folder(img_dir)
# Out:
# []

# %%
#load images floder
files=os.listdir(img_dir)
print(files)
# Out:
# ['lahore', 'islamabad']

# %%
dataimages=[]
label=[]
for i in files:
    dataimages.append(os.listdir(img_dir+'/'+i))
    for x in range(len(os.listdir(img_dir+'/'+i))):
      label.append(i)
#print(dataimages)
print(label)
# Out:
# ['lahore', 'lahore', 'lahore', 'lahore', 'lahore', 'lahore', 'lahore', 'lahore', 'islamabad', 'islamabad', 'islamabad', 'islamabad', 'islamabad', 'islamabad', 'islamabad', 'islamabad']
